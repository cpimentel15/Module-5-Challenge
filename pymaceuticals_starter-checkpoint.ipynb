# %% [markdown]
# # Pymaceuticals Inc.
# ---
#
# ### Analysis
#
# In this study, we begin by preparing the data through package dependency and data imports. Merging the mouse_metadata and study_results DataFrames into a single DataFrame enables us to analyze the tumor volume across various drug regimens. We uncover the number of unique mice IDs in the dataset and identify any mouse IDs with duplicate time points. By examining the data associated with these IDs, we create a new DataFrame, removing the duplicates for further analysis. Our cleaned DataFrame now serves as a reliable basis for the upcoming steps.
#
# Next, we delve into generating summary statistics, a crucial aspect of our analysis. Creating a DataFrame with summary statistics for each drug regimen allows us to compare their effectiveness. We calculate key metrics such as mean, median, variance, standard deviation, and the standard error of the mean (SEM) for tumor volume. This comprehensive overview enables us to identify potential trends and patterns in the data.-
#
# To better visualize and understand our results, we present the data using bar charts and pie charts. The bar charts illustrate the total number of mice and timepoints for each drug regimen. Utilizing both Pandas DataFrame.plot() and Matplotlib's pyplot methods, we provide compelling visualizations. Additionally, we display pie charts showing the distribution of female versus male mice in the study, helping us gain insights into the gender representation in the experimental cohort.
#
# Moving on, we analyze the final tumor volume for the most promising treatment regimens: Capomulin, Ramicane, Infubinol, and Ceftamin. We calculate quartiles and interquartile range (IQR) to identify potential outliers for each treatment. Employing Matplotlib, we create a box plot to visualize the distribution of the final tumor volume. We highlight any potential outliers, shedding light on treatments that require further scrutiny.
#
# To explore individual treatments in-depth, we choose a mouse treated with Capomulin and generate a line plot of tumor volume versus time point. This allows us to track the tumor's progress throughout the treatment. Furthermore, we examine the relationship between mouse weight and average tumor volume for the entire Capomulin regimen using a scatter plot. This reveals any correlations between the two variables, providing valuable insights into the treatment's impact on different body weights.
#
# Finally, we calculate the correlation coefficient and linear regression model for the Capomulin treatment regimen, illustrating the relationship between mouse weight and tumor volume. Plotting the linear regression model on the scatter plot, we gain a clear understanding of the trend and potential predictive power of the treatment. These findings contribute to our comprehensive analysis of cancer treatment efficacy and provide valuable information for future research and treatment strategies.
#
# In conclusion, this study offers an in-depth examination of cancer treatment efficacy across various drug regimens. By preparing the data, generating summary statistics, and visualizing the results, we gain valuable insights into potential trends and outliers. Additionally, we explore individual treatments, analyze correlations, and create regression models to comprehend the treatment's impact on tumor volume. This comprehensive analysis contributes to our understanding of cancer treatments and paves the way for further research and improved patient outcomes..

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st

# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single DataFrame

combined_data = pd.merge(study_results, mouse_metadata)

# Display the data table for preview

combined_data
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0        b128          0           45.000000                 0    Capomulin
# 1        b128          5           45.651331                 0    Capomulin
# 2        b128         10           43.270852                 0    Capomulin
# 3        b128         15           43.784893                 0    Capomulin
# 4        b128         20           42.731552                 0    Capomulin
# ...       ...        ...                 ...               ...          ...
# 1888     m601         25           33.118756                 1    Capomulin
# 1889     m601         30           31.758275                 1    Capomulin
# 1890     m601         35           30.834357                 1    Capomulin
# 1891     m601         40           31.378045                 1    Capomulin
# 1892     m601         45           28.430964                 1    Capomulin
#
#          Sex  Age_months  Weight (g)
# ...

# %%
# Checking the number of mice.
len(combined_data["Mouse ID"].value_counts())
# Out:
# 249

# %%
# Our data should be uniquely identified by Mouse ID and Timepoint
# Get the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 
duplicate_mice = combined_data[combined_data.duplicated(subset=["Mouse ID", "Timepoint"], keep=False)]
duplicate_mice["Mouse ID"].unique()
# Out:
# array(['g989'], dtype=object)

# %%
# Optional: Get all the data for the duplicate mouse ID. 
duplicate_mice
# Out:
#     Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 860     g989          0           45.000000                 0     Propriva
# 861     g989          0           45.000000                 0     Propriva
# 862     g989          5           48.786801                 0     Propriva
# 863     g989          5           47.570392                 0     Propriva
# 864     g989         10           51.745156                 0     Propriva
# 865     g989         10           49.880528                 0     Propriva
# 866     g989         15           51.325852                 1     Propriva
# 867     g989         15           53.442020                 0     Propriva
# 868     g989         20           55.326122                 1     Propriva
# 869     g989         20           54.657650                 1     Propriva
#
#         Sex  Age_months  Weight (g)
# 860  Female          21          26
# 861  Female          21          26
# ...

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
clean_data = combined_data.drop_duplicates(subset=["Mouse ID"]).loc[combined_data["Mouse ID"] != 'g989']

clean_data
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0        b128          0                45.0                 0    Capomulin
# 10       f932          0                45.0                 0     Ketapril
# 11       g107          0                45.0                 0     Ketapril
# 19       a457          0                45.0                 0     Ketapril
# 22       c819          0                45.0                 0     Ketapril
# ...       ...        ...                 ...               ...          ...
# 1848     t565          0                45.0                 0    Capomulin
# 1858     i557          0                45.0                 0    Capomulin
# 1868     m957          0                45.0                 0    Capomulin
# 1878     f966          0                45.0                 0    Capomulin
# 1883     m601          0                45.0                 0    Capomulin
#
#          Sex  Age_months  Weight (g)
# ...

# %%
# Checking the number of mice in the clean DataFrame.
len(clean_data["Mouse ID"].value_counts())

#this needs to be 248
# Out:
# 248

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

# Use groupby and summary statistical methods to calculate the following properties of each drug regimen: 
# mean, median, variance, standard deviation, and SEM of the tumor volume. 
# Assemble the resulting series into a single summary DataFrame.

summary_stats = combined_data.groupby('Drug Regimen')["Tumor Volume (mm3)"].agg(['mean', 'median', 'var', 'std'])

# Rename the columns for better understanding
summary_stats.rename(columns={
    'mean': 'Mean Tumor Volume',
    'median': 'Median Tumor Volume',
    'var': 'Variance',
    'std': 'Standard Deviation',
    'sem': 'SEM'
}, inplace=True)

# Print the summary statistics table
summary_stats
# Out:
#               Mean Tumor Volume  Median Tumor Volume   Variance  \
# Drug Regimen
# Capomulin             40.675741            41.557809  24.947764
# Ceftamin              52.591172            51.776157  39.290177
# Infubinol             52.884795            51.820584  43.128684
# Ketapril              55.235638            53.698743  68.553577
# Naftisol              54.331565            52.509285  66.173479
# Placebo               54.033581            52.288934  61.168083
# Propriva              52.322552            50.854632  42.351070
# Ramicane              40.216745            40.673236  23.486704
# Stelasyn              54.233149            52.431737  59.450562
# Zoniferol             53.236507            51.818479  48.533355
#
#               Standard Deviation
# Drug Regimen
# Capomulin               4.994774
# Ceftamin                6.268188
# Infubinol               6.567243
# Ketapril                8.279709
# Naftisol                8.134708
# ...

# %%
# A more advanced method to generate a summary statistics table of mean, median, variance, standard deviation,
# and SEM of the tumor volume for each regimen (only one method is required in the solution)

# Using the aggregation method, produce the same summary statistics in a single line

summary_stats = combined_data.groupby("Drug Regimen")["Tumor Volume (mm3)"].agg(
    mean=("mean"),
    median=("median"),
    var=("var"),
    std=("std"),
    sem=("sem")
)

summary_stats
# Out:
#                    mean     median        var       std       sem
# Drug Regimen
# Capomulin     40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin      52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol     52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril      55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol      54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo       54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva      52.322552  50.854632  42.351070  6.507770  0.512884
# Ramicane      40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn      54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol     53.236507  51.818479  48.533355  6.966589  0.516398

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of rows (Mouse ID/Timepoints) for each drug regimen using Pandas.

drug_regimen_counts = combined_data["Drug Regimen"].value_counts()

ax = drug_regimen_counts.plot(kind="bar", figsize=(10, 6), color="skyblue")

# Set the plot title and labels
ax.set_xlabel("Drug Regimen")
ax.set_ylabel("# of Observed Mourse Timepoints")

# Show the plot
plt.show()

# %%
# Generate a bar plot showing the total number of rows (Mouse ID/Timepoints) for each drug regimen using pyplot.

regimen_counts = combined_data["Drug Regimen"].value_counts()

plt.figure(figsize=(10, 6))
plt.bar(regimen_counts.index, regimen_counts.values, color="skyblue")


plt.xlabel("Drug Regimen")
plt.ylabel("# of Observed Mourse Timepoints")

plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using Pandas

gender_counts = combined_data["Sex"].value_counts()

ax = gender_counts.plot(kind="pie", figsize=(6, 6), autopct="%1.1f%%", colors=["lightpink", "lightblue"])
ax.set_title("Distribution of Female vs. Male Mice")

ax.set_ylabel('Sex')

plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot

gender_counts = combined_data["Sex"].value_counts()

plt.figure(figsize=(6, 6))
plt.pie(gender_counts, labels=gender_counts.index, autopct="%1.1f%%", colors=["lightpink", "lightskyblue"], startangle=140)

plt.title("Distribution of Female vs. Male Mice")
plt.ylabel("Sex")

plt.show()

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin

selected_regimens = ["Capomulin", "Ramicane", "Infubinol", "Ceftamin"]

# Start by getting the last (greatest) timepoint for each mouse
max_timepoints = combined_data.loc[combined_data["Drug Regimen"].isin(selected_regimens)].groupby("Mouse ID")["Timepoint"].max()

# Merge this group df with the original DataFrame to get the tumor volume at the last timepoint

final_tumor_volume_df = pd.merge(max_timepoints, combined_data, on=["Mouse ID", "Timepoint"])
final_tumor_volume_df
# Out:
#    Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0      a203         45           67.973419                 2    Infubinol
# 1      a251         45           65.525743                 1    Infubinol
# 2      a275         45           62.999356                 3     Ceftamin
# 3      a411         45           38.407618                 1     Ramicane
# 4      a444         45           43.047543                 0     Ramicane
# ..      ...        ...                 ...               ...          ...
# 95     y769         45           68.594745                 4     Ceftamin
# 96     y793         45           31.896238                 2    Capomulin
# 97     y865         45           64.729837                 3     Ceftamin
# 98     z578         45           30.638696                 0     Ramicane
# 99     z581         45           62.754451                 3    Infubinol
#
#        Sex  Age_months  Weight (g)
# 0   Female          20          23
# ...

# %%
# Put treatments into a list for for loop (and later for plot labels)


# Create empty list to fill with tumor vol data (for plotting)


# Calculate the IQR and quantitatively determine if there are any potential outliers. 

    
    # Locate the rows which contain mice on each drug and get the tumor volumes

    
    # add subset 

    
    # Determine outliers using upper and lower bounds
    
treatments = ["Capomulin", "Ramicane", "Infubinol", "Ceftamin"]

tumor_vol_data = []


for treatment in treatments:
    
    tumor_volumes = final_tumor_volume_df.loc[final_tumor_volume_df["Drug Regimen"] == treatment, "Tumor Volume (mm3)"]
    tumor_vol_data.append(tumor_volumes)
    
    quartiles = tumor_volumes.quantile([0.25, 0.5, 0.75])
    lower_q = quartiles[0.25]
    upper_q = quartiles[0.75]
    iqr = upper_q - lower_q
    
    lower_bound = lower_q - 1.5 * iqr
    upper_bound = upper_q + 1.5 * iqr
    
    potential_outliers = tumor_volumes.loc[(tumor_volumes < lower_bound) | (tumor_volumes > upper_bound)]
    print(f"{treatment}'s potential outliers: {potential_outliers}")
# Out:
# Capomulin's potential outliers: Series([], Name: Tumor Volume (mm3), dtype: float64)
# Ramicane's potential outliers: Series([], Name: Tumor Volume (mm3), dtype: float64)
# Infubinol's potential outliers: 15    36.321346
# Name: Tumor Volume (mm3), dtype: float64
# Ceftamin's potential outliers: Series([], Name: Tumor Volume (mm3), dtype: float64)

# %%
# Generate a box plot that shows the distrubution of the tumor volume for each treatment group.

tumor_vol_data = [final_tumor_volume_df.loc[final_tumor_volume_df["Drug Regimen"] == treatment, "Tumor Volume (mm3)"] for treatment in treatments]

fig, ax = plt.subplots()

ax.boxplot(tumor_vol_data, labels=treatments)

ax.set_xlabel("Drug Regimen")
ax.set_ylabel("Tumor Volume (mm3)")

plt.show()

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of tumor volume vs. time point for a single mouse treated with Capomulin


# Step 1: Filter the data for Capomulin treatment
capomulin_data = combined_data.loc[combined_data["Drug Regimen"] == "Capomulin"]

# Step 2: Select a single mouse from the Capomulin-treated mice (e.g., mouse_id = 's185')
mouse_id = 'l509'
selected_mouse_data = capomulin_data.loc[capomulin_data["Mouse ID"] == mouse_id]

# Step 3: Generate the line plot
plt.plot(selected_mouse_data["Timepoint"], selected_mouse_data["Tumor Volume (mm3)"])
plt.xlabel("Timepoint (days)")
plt.ylabel("Tumor Volume (mm3)")
plt.title(f"Capomulin Treatment of Mouse {mouse_id}")

plt.show()

# %%
# Generate a scatter plot of mouse weight vs. the average observed tumor volume for the entire Capomulin regimen


capomulin_data = combined_data.loc[combined_data["Drug Regimen"] == "Capomulin"]

average_tumor_volume = capomulin_data.groupby("Mouse ID")["Tumor Volume (mm3)"].mean()
mouse_weight = capomulin_data.groupby("Mouse ID")["Weight (g)"].mean()


plt.scatter(mouse_weight, average_tumor_volume, marker="o", color="b")
plt.xlabel("Weight (g)")
plt.ylabel("Average Tumor Volume")

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and a linear regression model 
# for mouse weight and average observed tumor volume for the entire Capomulin regimen

correlation_coefficient = mouse_weight.corr(average_tumor_volume)

slope, intercept, r_value, p_value, std_err = st.linregress(mouse_weight, average_tumor_volume)

plt.scatter(mouse_weight, average_tumor_volume, marker="o", color="b")
plt.xlabel("Weight (g)")
plt.ylabel("Average Tumor Volume")

plt.plot(mouse_weight, slope * mouse_weight + intercept, color="r")

plt.show()

print(f"The correlation between mouse weight and the average tumor volume is {correlation_coefficient:.2f}")
# Out:
# The correlation between mouse weight and the average tumor volume is 0.84
